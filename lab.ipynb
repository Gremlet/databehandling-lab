# %% [markdown]
# ## Databehandling lab

# %% [markdown]
# (a) Use the `pd.read_csv()` function to read the data into Python. Call the loaded data `college`. Make sure that you have the directory set to the correct location for the data.

# %%
import pandas as pd

college = pd.read_csv("./data/College.csv")

# %% [markdown]
# (b) Look at the data used in the notebook by creating and running a new cell with just the code `college` in it. You should notice that the first column is just the name of each university in column named something like Unnamed: 0. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later. Try the following commands and similarly look at
# the resulting data frames:
#
# ```python
# 1 college2 = pd . read_csv ( ’ College . csv ’ , index_col =0)
# 2 college3 = college . rename ({ ’ Unnamed : 0 ’: ’ College ’} , axis =1)
# 3 college3 = college3 . set_index ( ’ College ’)
# ```
#
# This has used the first column in the file as an index for the data frame. This means that pandas has given each row a name corresponding to the appropriate university. Now you should see that the first data column is Private. Note that the names of the colleges appear on the left of the table. Overwrite your modified version to the data with the following: `college = college3`

# %%
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
college2 = pd.read_csv("./data/College.csv", index_col=0)
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
college3 = college.rename({"Unnamed: 0": "College"}, axis=1)
college3 = college3.set_index("College")
college = college3
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %% [markdown]
# (c) Use the `describe()` method of college to produce a numerical summary of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (d) Use the `pd.plotting.scatter_matrix()` function to produce a scatterplot matrix of the first columns `[Top10perc, Apps, Enroll]`. Recall that you can reference a list `C` of columns of a data frame `A` using `A[C]`.

# %%
pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# (e) Use the `boxplot()` method of `college` to produce side-by-side boxplots of `Outstate` versus `Private`.

# %%
import matplotlib.pyplot as plt

college.boxplot(column="Outstate", by="Private")
plt.title("Out-of-state tuition vs Private/Public status")
plt.suptitle("")
plt.xlabel("Private")
plt.ylabel("Out of state tuition")
# Out:
# Text(0, 0.5, 'Out of state tuition')

# %% [markdown]
# (f) Create a new qualitative (yes/no) variable, called Elite, by binning the `Top10perc` variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%.
#
# ```python
# college ['Elite'] = pd.cut(college['Top10perc'], [0, 0.5, 1], labels=['No', 'Yes'])
# ```
#
# Use the value_counts() method of `college['Elite']` to see how many elite universities there are. Finally, use the `boxplot()` method again to produce side-by-side boxplots of Outstate versus Elite.

# %%
college["Elite"] = pd.cut(college["Top10perc"], [0, 50, 100], labels=["No", "Yes"])

college["Elite"].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot(column="Outstate", by="Elite")
plt.title("Out-of-state tuition vs Elite status")
plt.suptitle("")
plt.xlabel("Elite")
plt.ylabel("Out of state tuition")
# Out:
# Text(0, 0.5, 'Out of state tuition')

# %% [markdown]
# (g) Use the `plot.hist()` method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command `plt.subplots(2, 2)` may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations

# %%
fig, ax = plt.subplots(2, 3, figsize=(16, 10))

college["Apps"].plot.hist(ax=ax[0, 0], bins=20).set(title="Apps")
college["Apps"].plot.hist(ax=ax[1, 0], bins=100).set(title="Apps")
college["Top10perc"].plot.hist(ax=ax[0, 1], bins=30).set(title="Top10perc")
college["Top10perc"].plot.hist(ax=ax[1, 1], bins=50).set(title="Top10perc")
college["Grad.Rate"].plot.hist(ax=ax[0, 2], bins=10).set(title="Grad.Rate")
college["Grad.Rate"].plot.hist(ax=ax[1, 2], bins=100).set(title="Grad.Rate")
# Out:
# [Text(0.5, 1.0, 'Grad.Rate')]

# %% [markdown]
# (h) Continue exploring the data, and provide a brief summary of what you discover. Describe what you are looking for and what you find. For example, are there any correlations between personal spending, instructional spending and Elite status?

# %% [markdown]
# 1. One thing I noticed, when plotting the above histograms was that there was an odd value for one college in `Grad.Rate`. Cazenovia college has a graduation rate of 118, which is not possible, as it should be the proportion of students graduating within a certain time frame, so the maximum logical value is 100%

# %%
college.loc[college["Grad.Rate"] > 100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate Elite
# College
# Cazenovia College        118    No

# %% [markdown]
# There are a few ways one could deal with this anomaly.
#
# - Clipping: `college["Grad.Rate"] = college["Grad.Rate"].clip(upper=100)`
# - Manual correction: setting that one row to 100 or the median.
# - Removal: dropping it from analysis if it’s just a single outlier.

# %% [markdown]
# ---

# %% [markdown]
# 2. I found that there are only a few universities that spend more that $30,000 per student (9) and of those 9, only one is not Elite

# %%
college.loc[college["Expend"] > 30000].groupby("Elite", observed=False).size()
# Out:
# Elite
# No     1
# Yes    8
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# 3. Do colleges with more applications also accept more students?

# %%
college["Apps"].corr(college["Accept"])
# Out:
# np.float64(0.9434505720431933)

# %% [markdown]
# - That is a very strong correlation with an r-value of 0.94. Let's check if this is statistically significant by getting the p-value.

# %%
from scipy.stats import pearsonr

r, p = pearsonr(college["Apps"], college["Accept"])
print("r:", r)
print("p:", p)
# Out:
# r: 0.9434505720431934
# p: 0.0

# %% [markdown]
# - The p-value is < 0.05 so the correlation is, indeed, significant i.e. the observed relationship is unlikely to have occurred by chance.

# %% [markdown]
# ---

# %% [markdown]
# 4. I hypothesised that elite colleges would accept a lower proportion of students in relation to number of applications. And, if this is the case, is the accept/apps ratio lower at larger elite universities?

# %%
college["Admit.Rate"] = (college["Accept"] / college["Apps"]) * 100

college.groupby("Elite")["Admit.Rate"].mean()
# Out:
# /var/folders/z6/lqrq2m_5737_gdx8z2b2c2v00000gn/T/ipykernel_76975/1416453134.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   college.groupby("Elite")["Admit.Rate"].mean()
# Elite
# No     76.963792
# Yes    54.340927
# Name: Admit.Rate, dtype: float64

# %% [markdown]
# I calculated the acceptance rate (($Accept/Apps) * 100$) for each school and found that non-elite colleges accept about 77% of applicants on average, while elite colleges accept around 54%. This supports the idea that elite institutions are more selective, both because of prestige and because they receive more applications than they can enrol.
#
# Now, to see if the ratio is any different at larger elite universities. Let's say that the largest 10% (by number of undergrads) count as large for this purpose.

# %%
elite_only = college[college["Elite"] == "Yes"]

cutoff = elite_only["F.Undergrad"].quantile(0.9)

college["large_elite"] = (college["Elite"] == "Yes") & (college["F.Undergrad"] > cutoff)

elite_only.groupby(elite_only["F.Undergrad"] > cutoff)["Admit.Rate"].mean()
# Out:
# F.Undergrad
# False    54.051482
# True     56.873566
# Name: Admit.Rate, dtype: float64

# %% [markdown]
# The acceptance rate in the largest 10% of elites is similar to the elite acceptance rate, 56% vs 54%. I initially expected the largest elite schools to have the lowest acceptance rates; the kind of extremely selective behaviour associated with Ivy League or top 10 universities. And this could still actually be the case because the College dataset’s definition of “elite” (Top10perc > 50%) captures academically strong institutions, but not necessarily the ultra-elites with very low acceptance rates. Within this broader elite group, size didn’t make schools more selective; the acceptance rate remained roughly the same whether the school was large or small.
#
# Out of curiosity, I decided to check what the acceptance rates for the Ivy League colleges in the dataset are.

# %%
# The eight Ivies are Brown University, Columbia University, Cornell University,
# Dartmouth College, Harvard University, University of Pennsylvania, Princeton University, and Yale University.
# Cornell University is not in the dataset

ivy = [
    "Harvard University",
    "Yale University",
    "Princeton University",
    "Columbia University",
    "Brown University",
    "Dartmouth College",
    "University of Pennsylvania",
]

ivy_df = college.loc[college.index.isin(ivy)]

print(ivy_df["Admit.Rate"].sort_values())

ivy_df["Admit.Rate"].mean()
# Out:
# College
# Princeton University          15.448631
# Harvard University            15.614858
# Yale University               22.914526
# Brown University              25.734944
# Dartmouth College             26.470246
# Columbia University           28.567200
# University of Pennsylvania    42.213975
# Name: Admit.Rate, dtype: float64
# np.float64(25.280625353022234)

# %% [markdown]
# The mean acceptance rate at Ivy League universities is, indeed, well below the Elite average at about 25%. That the Ivies behave differently from the dataset's Elite colleges is what I was expecting.

# %% [markdown]
# ---

# %% [markdown]
# 5. I wanted an overview of what other correlations might exist and thought a heatmap could give some nice visual insight.

# %%
import seaborn as sns

# get only numeric columns, as we can't use corr with categorical columns like Elite
college_numeric = college.select_dtypes(include="number")

corr_matrix = college_numeric.corr()

sns.heatmap(corr_matrix, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# - This shows some interesting correlations. Some are fairly obvious, like `Outstate` and `Expend` have a fairly strong positive correlation. We would expect that out-of-state tuition is higher at colleges that spend more per student. Some maybe a bit less obvious; like the modest negative correlation between `Room.Board` and `S.F.Ratio` meaning colleges with lower student-to-faculty ratios (i.e., more faculty per student) tend to charge more for room and board. To be expected, perhaps; but it's not a correlation I would have thought about off the top of my head. This shows that visualising correlations can be really useful; patterns you wouldn't necessarily think of can emerge.

# %% [markdown]
# ---

# %% [markdown]
# ### Aside
#
# This might be beyond the scope of this lab but I found it very interesting how data invites human speculation. For instance, when I was looking into the odd 118% graduation rate outlier, I wondered which colleges have the lowest graduation rates and I noticed that Brigham Young University had a graduation rate of only 33%. That was surprising, as by all accounts BYU is a very decent university. That curiosity sent me looking for context, not for the sake of this lab, but because the number felt counterintuitive. It turns out that the explanation is largely cultural rather than academic. From a former BYU student ([source](https://www.quora.com/What-are-the-main-reasons-why-students-from-BYU-dont-graduate-on-time)):
#
# > Without having actual statistics, and basing my answer on my observations there:
# >
# > 1. The mission puts you much older than typical students. Graduating on time at BYU means 24, not 22 years old.
# > 2. Family commitments: Mormons are much more likely to marry young, and then have kids. I knew many BYU students with children. The mother often dropped out to raise the kids and work part time so the father could finish his studies.
# > 3. Working: many Mormons don’t want a lot of student debt, so they work part time and take fewer courses. Former BYU President Rex Lee tried to fight this by telling students to graduate and pay off loans, but the temptation to work and pay as you go.
# > 4. I hope this has changed, but many women went to BYU get married. They called that the MRS degree. They would drop out after marrying or having kids, or wait until the kids were older to finish. I believe BYU is still one of the few schools where men are more likely to graduate than women. Women outnumber men in college attendance, except in Utah Nationally, women are far outpacing men, and now hold more degrees despite decades of being behind.
# > 5. Mormons do value education, but mostly for pragmatic reasons. They are encouraged to get high paying professions to raise their families and to help build up the church. They are not encouraged to go into the humanities or get educations purely for personal pleasure.
#
# This made me realise something kind of fun about this whole process; exploring this kind of data can tell you _what_ is happening, but it also makes you wonder about the _why_ and this can lead you to sociology, culture, history, behaviour, psychology etc. All the complex and messy human stuff that doesn't fit neatly into a `.csv` I know that my little BYU dive isn't "data" in the formal sense. It was just me following a curiosity sparked by an odd number. But I love that numbers can push you to ask questions that the dataset can't fully answer.
#
# Also, while curiosity is great and it can definitely help you generate hypotheses, you have to be careful not to let the "why" that you find (and any biases that come with it) override what the data _actually_ shows.
